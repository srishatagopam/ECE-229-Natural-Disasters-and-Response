# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:60% !important; }</style>"))
import warnings
warnings.filterwarnings('ignore')

from custom_code.major_disaster_analysis import *
from custom_code.ML_models.disaster_cpi_prediction import *
from custom_code.ML_models.realtime_earthquake_prediction import *
from custom_code.ML_models.stacked_bar import *
from custom_code.ML_models.dis_trends import *

df1 = pd.read_csv('./datasets/1970-2022_DISASTERS.xlsx - emdat data.csv')
df1=df1.drop(columns=['Seq','Glide','Disaster Group', 'OFDA Response', 'Appeal', 'Declaration', 'Aid Contribution', 
                    'Associated Dis', 'Associated Dis2', 'Dis Mag Value', 'Dis Mag Scale',
                     'Insured Damages (\'000 US$)', 'Adm Level', 'Admin1 Code', 'Admin2 Code', 'Event Name'])
df1 = df1[~(df1['Disaster Type'].isin(["Insect infestation", "Animal accident","Impact","Glacial lake outburst","Fog","Mass movement (dry)"]))]


df2= pd.read_csv('./datasets/1900-2022_DISASTERS.xlsx - emdat data.csv')
df2=df2.drop(columns=['Seq','Glide','Disaster Group', 'OFDA Response', 'Appeal', 'Declaration', 'Aid Contribution', 
                    'Associated Dis', 'Associated Dis2', 'Dis Mag Value', 'Dis Mag Scale',
                     'Insured Damages (\'000 US$)', 'Adm Level', 'Admin1 Code', 'Admin2 Code', 'Event Name'])

df2 = df2[~(df2['Disaster Type'].isin(["Insect infestation", "Animal accident","Impact","Glacial lake outburst","Fog","Mass movement (dry)"]))]
# Out:
# <style>.container { width:60% !important; }</style>

# %%
map_distribution_cases(df1, voila=False)
# Out:
# Column
#     [0] Markdown(str)
#     [1] Row
#         [0] DateRangeSlider(end=datetime.datetime(2023, ..., name='Year Range', start=datetime.datetime(1970, ..., value=(datetime.datetime(1970, ..., value_end=datetime.datetime(2023, ..., value_start=datetime.datetime(1970, ...)
#         [1] Select(name='What to see?', options=['# Disasters', ...], value='# Disasters')
#     [2] HoloViews(DynamicMap)

# %%
dis_analysis_(df1)
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'99def019-db25-4578-aba8-4261b2db5e5d': {'defs': …

# %%
dis_analysis(df1, voila=False)
# Out:
# Column
#     [0] Markdown(str)
#     [1] Row
#         [0] Select(name='Damage Type', options=['Disaster Occurence', ...], value='Disaster Occurence')
#     [2] HoloViews(DynamicMap)

# %%
cpi_prediction_module(voila=False)
# Out:
# WARNING:param.wrapped: Callable raised "AttributeError("'GeoDataFrame' object has no attribute 'overlay'")".
# Invoked as wrapped(year=2023, month=1, disaster_type='Earthquake')
# WARNING:param.dynamic_operation: Callable raised "AttributeError("'GeoDataFrame' object has no attribute 'overlay'")".
# Invoked as dynamic_operation(year=2023, month=1, disaster_type='Earthquake')
# [17:54:12] WARNING: c:\ci\xgboost-split_1638290375667\work\src\objective\regression_obj.cu:188: reg:linear is now deprecated in favor of reg:squarederror.
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\harsh\anaconda3\envs\ece229\lib\site-packages\IPython\core\formatters.py", line 222, in catch_format_error
#     r = method(self, *args, **kwargs)
#   File "C:\Users\harsh\anaconda3\envs\ece229\lib\site-packages\IPython\core\formatters.py", line 973, in __call__
#     return method(include=include, exclude=exclude)
# ...

# %%
predicted_earthquake_module(voila=False)
# Out:
# [17:54:14] WARNING: ..\src\learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 predicted_earthquake_module(voila=False)
#
# File ~\ECE-229-Natural-Disasters-and-Response\custom_code\ML_models\realtime_earthquake_prediction.py:335, in predicted_earthquake_module(voila)
#     333 df_past = df_past.drop_duplicates()
#     334 _,ax_past = plot_interactive_scattermap(df_past, '', 5,indep=True)
# --> 335 days_inter, df_output = predict_earthquake_model(df_past, df_future)
# ...
